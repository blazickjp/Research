# %%
import mixtures
import matplotlib.colors as mcolors

# %%
list(mcolors.TABLEAU_COLORS.values())[0]
# Out:
# '#1f77b4'

# %%
gmm = mixtures.FiniteGMM(2, [1,4], [.5,3], [.5, .5])

# %%
gmm.dataGen(100)

# %%
gmm.plot_data(alph = .05)
# Out:
# #1f77b4
# #ff7f0e
